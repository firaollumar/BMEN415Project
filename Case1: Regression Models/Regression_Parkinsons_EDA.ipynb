# %% [markdown]
# # Parkinsons-Telemonitoring  - Exploratory Data Analysis-BMEN 415 - Group 07
#
# ### Purpose: The purpose of this notebook is to perform Explorartory Data Analysis on Parkinsons-Telemonitoring Raw Data.
#
#
#
#
# #### Features:
#
#  1   age
#  2   sex
#  3   test_time
#  4   motor_UPDRS
#  5   total_UPDRS
#  6   Jitter(%)
#  7   Jitter(Abs)
#  8   Jitter:RAP
#  9   Jitter:PPQ5
#  10  Jitter:DDP
#  11  Shimmer
#  12  Shimmer(dB)
#  13  Shimmer:APQ3
#  14  Shimmer:APQ5
#  15  Shimmer:APQ11
#  16  Shimmer:DDA
#  17  NHR
#  18  HNR
#  19  RPDE
#  20  DFA
#  21  PPE
#
#
# __Contact: BMEN415, Group 07__
#
# Brielle Lillywhite,
# Huda Abbas,
# Noel Thomas,
# Raksha Achar,
# Firaoll Umar

# %%
import numpy as np  # Importing NumPy library
import pandas as pd  # Importing Pandas library
import matplotlib.pyplot as plt  # Importing Matplotlib library's "pyplot" module
import seaborn as sns  # Imorting Seaborn library

import os

# %%
data = pd.read_csv("parkinsons_updrs.data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %%
data.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
data.tail()
# Out:
#       subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 5870        42   61    0     142.79       22.485       33.485    0.00406
# 5871        42   61    0     149.84       21.988       32.988    0.00297
# 5872        42   61    0     156.82       21.495       32.495    0.00349
# 5873        42   61    0     163.73       21.007       32.007    0.00281
# 5874        42   61    0     170.73       20.513       31.513    0.00282
#
#       Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 5870     0.000031     0.00167      0.00168  ...        0.160       0.00973
# 5871     0.000025     0.00119      0.00147  ...        0.215       0.01052
# 5872     0.000025     0.00152      0.00187  ...        0.244       0.01371
# 5873     0.000020     0.00128      0.00151  ...        0.131       0.00693
# 5874     0.000021     0.00135      0.00166  ...        0.171       0.00946
#
# ...

# %%
data.describe()
# Out:
#           subject#          age          sex    test_time  motor_UPDRS  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     21.494128    64.804936     0.317787    92.863722    21.296229
# std      12.372279     8.821524     0.465656    53.445602     8.129282
# min       1.000000    36.000000     0.000000    -4.262500     5.037700
# 25%      10.000000    58.000000     0.000000    46.847500    15.000000
# 50%      22.000000    65.000000     0.000000    91.523000    20.871000
# 75%      33.000000    72.000000     1.000000   138.445000    27.596500
# max      42.000000    85.000000     1.000000   215.490000    39.511000
#
#        total_UPDRS    Jitter(%)  Jitter(Abs)   Jitter:RAP  Jitter:PPQ5  ...  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000  ...
# mean     29.018942     0.006154     0.000044     0.002987     0.003277  ...
# std      10.700283     0.005624     0.000036     0.003124     0.003732  ...
# ...

# %%
data.corr()
# Out:
#                subject#       age       sex  test_time  motor_UPDRS  \
# subject#       1.000000 -0.030864  0.286851  -0.000882     0.252919
# age           -0.030864  1.000000 -0.041602   0.019884     0.273665
# sex            0.286851 -0.041602  1.000000  -0.009805    -0.031205
# test_time     -0.000882  0.019884 -0.009805   1.000000     0.067918
# motor_UPDRS    0.252919  0.273665 -0.031205   0.067918     1.000000
# total_UPDRS    0.253643  0.310290 -0.096559   0.075263     0.947231
# Jitter(%)      0.135448  0.023071  0.051422  -0.022837     0.084816
# Jitter(Abs)    0.075156  0.035691 -0.154645  -0.011365     0.050903
# Jitter:RAP     0.120339  0.010255  0.076718  -0.028888     0.072684
# Jitter:PPQ5    0.136474  0.013199  0.087995  -0.023290     0.076291
# Jitter:DDP     0.120350  0.010258  0.076703  -0.028876     0.072698
# Shimmer        0.146202  0.101554  0.058736  -0.033870     0.102349
# Shimmer(dB)    0.142864  0.111130  0.056481  -0.030962     0.110076
# ...

# %%
fig, axes = plt.subplots(figsize=(18, 18)) 
sns.heatmap(data=data.corr(), annot=True, linewidths=.5, ax=axes) 
plt.show()

# %%
fig, axes = plt.subplots(nrows=10, ncols=2, figsize=(12, 80))
data.plot(kind="hist", y="motor_UPDRS", bins=70, color="b", ax=axes[0][0])
data.plot(kind="hist", y="total_UPDRS", bins=200, color="r", ax=axes[0][1])
data.plot(kind="hist", y="age", bins=5, color="g", ax=axes[1][0])
data.plot(kind="hist", y="Jitter(%)", bins=200, color="orange", ax=axes[1][1])
data.plot(kind="hist", y="Jitter(Abs)", bins=70, color="b", ax=axes[2][0])
data.plot(kind="hist", y="Jitter:RAP", bins=200, color="r", ax=axes[2][1])
data.plot(kind="hist", y="Jitter:PPQ5", bins=5, color="g", ax=axes[3][0])
data.plot(kind="hist", y="Jitter:DDP", bins=200, color="orange", ax=axes[3][1])
data.plot(kind="hist", y="Shimmer", bins=70, color="b", ax=axes[4][0])
data.plot(kind="hist", y="Shimmer(dB)", bins=200, color="r", ax=axes[4][1])
data.plot(kind="hist", y="Shimmer:APQ3", bins=5, color="g", ax=axes[5][0])
data.plot(kind="hist", y="Shimmer:APQ5", bins=200, color="orange", ax=axes[5][1])
data.plot(kind="hist", y="Shimmer:DDA", bins=70, color="b", ax=axes[6][0])
data.plot(kind="hist", y="Shimmer:APQ11", bins=200, color="r", ax=axes[6][1])
data.plot(kind="hist", y="NHR", bins=5, color="g", ax=axes[7][0])
data.plot(kind="hist", y="HNR", bins=200, color="orange", ax=axes[7][1])
data.plot(kind="hist", y="RPDE", bins=200, color="orange", ax=axes[8][0])
data.plot(kind="hist", y="DFA", bins=70, color="b", ax=axes[8][1])
data.plot(kind="hist", y="PPE", bins=5, color="g", ax=axes[9][0])
plt.show()

# %%
sns.catplot(x="sex", kind="count", palette="Set1", data=data)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5))
data.plot(kind='scatter', x='age', y='total_UPDRS', alpha=0.5, color='green', ax=axes[0], title="Age vs. UPDRS")
data.plot(kind='scatter', x='Jitter(%)', y='total_UPDRS', alpha=0.5, color='red', ax=axes[1], title="Jitter(%) vs. UPDRS")
data.plot(kind='scatter', x='Shimmer(dB)', y='total_UPDRS', alpha=0.5, color='blue', ax=axes[2], title="Shimmer(dB) vs. UPDRS")
plt.show()

# %% [markdown]
# __Group 7's Conclusion:__
#
# Perferred Features (Least Correlated with each other):
#
# PPE
# AGE
# Shimmer
# Shimmer DB
# Shimmer APQ11
# HNR
# RPDE
# DFA
# PPE
#
#
# __We generally want to avoid features that are highly correlated with each other as models' assumption is that these features are unrelated to each other,but highly correlated to the dependant variable.__
